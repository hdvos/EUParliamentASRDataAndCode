# %%
import os

# %%
transcriptions_file_name = 'manual_transcriptions.csv'
transcriptions_file_path = '../transcriptions/'
transcriptions_file = os.path.join(transcriptions_file_path, transcriptions_file_name)
transcriptions_file
# Out:
# '../transcriptions/manual_transcriptions.csv'

# %%
if not os.path.exists(transcriptions_file) and os.path.exists(transcriptions_file.replace('.csv', '.ods')):
    print("File does not exist. Please convert .ods file to .csv")
    raise RuntimeError

# %%
import pandas as pd

# %%
transcriptions_df = pd.read_csv(transcriptions_file, sep='\t')
transcriptions_df
# Out:
#                Sound_file  Length (s)  \
# 0    016_20140701.wav.pcm          22
# 1    017_20140701.wav.pcm          27
# 2    018_20140701.wav.pcm          15
# 3    019_20140701.wav.pcm          23
# 4    020_20140701.wav.pcm          28
# ..                    ...         ...
# 96   144_20141120.wav.pcm          25
# 97   145_20141120.wav.pcm          16
# 98   146_20141120.wav.pcm          22
# 99   147_20141120.wav.pcm          17
# 100  232_20141211.wav.pcm          29
#
#                                          Transcription  nr_words  \
# 0    I would like to propose on behalf of the snd g...        33
# 1    no, I ask then the nominated candidate whether...        40
# 2    and as there is only one candidate, I would li...        43
# 3    so lets do it by acclamation, congratulation m...        24
# 4                       thank you very much colleagues         5
# ..                                                 ...       ...
# 96   the commissions commitment to putting an indep...        67
# 97   It has to be immune from European and national...        38
# 98   Therefore, the appointment procedure for them ...        59
# 99   It is important to recall that at the local le...        56
# 100  now, with regard to ehm ehm ehm ehm, protectio...        60
#
#      words per second
# 0            1.500000
# 1            1.481481
# 2            2.866667
# 3            1.043478
# 4            0.178571
# ..                ...
# 96           2.680000
# 97           2.375000
# 98           2.681818
# 99           3.294118
# 100          2.068966
#
# [101 rows x 5 columns]

# %% [markdown]
# #### Create 4 columns:
#
# * preprocessed manual transcription
# * ASR output
# * preprocessed ASR output
# * WER

# %%
import re
import numpy as np
def preprocess_text(transcription):
    if not type(transcription) is str:
#         input(transcription)
        return ''
    transcription = transcription.lower()
    
    transcription = re.sub(r'[^\w\s]',' ',transcription)
    transcription = re.sub(r'\s+',' ',transcription)
    return transcription

# %%
transcriptions_df["preprocessed_transcription"] = transcriptions_df.Transcription.apply(preprocess_text)
transcriptions_df.preprocessed_transcription
# Out:
# 0      i would like to propose on behalf of the snd g...
# 1      no i ask then the nominated candidate whether ...
# 2      and as there is only one candidate i would lik...
# 3      so lets do it by acclamation congratulation mi...
# 4                         thank you very much colleagues
#                              ...
# 96     the commissions commitment to putting an indep...
# 97     it has to be immune from european and national...
# 98     therefore the appointment procedure for them m...
# 99     it is important to recall that at the local le...
# 100    now with regard to ehm ehm ehm ehm protection ...
# Name: preprocessed_transcription, Length: 101, dtype: object

# %%
from zipfile import ZipFile
zipfiles_path = '../ASR_output/the_transcripts'


def get_filename_of_output(sound_file_name):
    filename = sound_file_name
    bare_filename = filename.split('.')[0]
    id_1, id_2 = bare_filename.split('_')
    zipfile = f'{id_2}.zip'
    zipfile_path = os.path.join(zipfiles_path, zipfile)
    member = os.path.join(id_2, f"{id_1}_{id_2}.wav.pcm.txt")
    return {
        'zipfile': zipfile_path,
        'member': member
    }

def get_asr_output(sound_file_name):
    file_info = get_filename_of_output(sound_file_name)
    
    try:
        with ZipFile(file_info['zipfile'], 'r') as zipobj:
            text = zipobj.read(file_info['member']).decode("utf-8")
    except FileNotFoundError:
        text = ''
    
    return text

# %%
transcriptions_df['asr_output'] = transcriptions_df.Sound_file.apply(get_asr_output)
transcriptions_df.head()
# Out:
#              Sound_file  Length (s)  \
# 0  016_20140701.wav.pcm          22
# 1  017_20140701.wav.pcm          27
# 2  018_20140701.wav.pcm          15
# 3  019_20140701.wav.pcm          23
# 4  020_20140701.wav.pcm          28
#
#                                        Transcription  nr_words  \
# 0  I would like to propose on behalf of the snd g...        33
# 1  no, I ask then the nominated candidate whether...        40
# 2  and as there is only one candidate, I would li...        43
# 3  so lets do it by acclamation, congratulation m...        24
# 4                     thank you very much colleagues         5
#
#    words per second                         preprocessed_transcription  \
# 0          1.500000  i would like to propose on behalf of the snd g...
# 1          1.481481  no i ask then the nominated candidate whether ...
# 2          2.866667  and as there is only one candidate i would lik...
# 3          1.043478  so lets do it by acclamation congratulation mi...
# 4          0.178571                     thank you very much colleagues
#
#                                           asr_output
# 0  I WOULD LIKE TO PROPOSE ON BEHALF OF THIES AND...
# 1  NO I ASK THAN A A DENOMINATED CANDIDE WETHER H...
# 2  AND AS THERE IS ONLY ONE CANDIDATE I WOULD LIK...
# 3  SO A LEX DOID BY ACCLAMATION CONGRATULATION ST...
# 4                        THANK YOU VERY MUCH GOEX OO

# %%
transcriptions_df['asr_output_preprocessed'] = transcriptions_df.asr_output.apply(preprocess_text)
transcriptions_df.head()
# Out:
#              Sound_file  Length (s)  \
# 0  016_20140701.wav.pcm          22
# 1  017_20140701.wav.pcm          27
# 2  018_20140701.wav.pcm          15
# 3  019_20140701.wav.pcm          23
# 4  020_20140701.wav.pcm          28
#
#                                        Transcription  nr_words  \
# 0  I would like to propose on behalf of the snd g...        33
# 1  no, I ask then the nominated candidate whether...        40
# 2  and as there is only one candidate, I would li...        43
# 3  so lets do it by acclamation, congratulation m...        24
# 4                     thank you very much colleagues         5
#
#    words per second                         preprocessed_transcription  \
# 0          1.500000  i would like to propose on behalf of the snd g...
# 1          1.481481  no i ask then the nominated candidate whether ...
# 2          2.866667  and as there is only one candidate i would lik...
# 3          1.043478  so lets do it by acclamation congratulation mi...
# 4          0.178571                     thank you very much colleagues
#
#                                           asr_output  \
# 0  I WOULD LIKE TO PROPOSE ON BEHALF OF THIES AND...
# 1  NO I ASK THAN A A DENOMINATED CANDIDE WETHER H...
# 2  AND AS THERE IS ONLY ONE CANDIDATE I WOULD LIK...
# 3  SO A LEX DOID BY ACCLAMATION CONGRATULATION ST...
# 4                        THANK YOU VERY MUCH GOEX OO
#
#                              asr_output_preprocessed
# 0  i would like to propose on behalf of thies and...
# 1  no i ask than a a denominated candide wether h...
# 2  and as there is only one candidate i would lik...
# 3  so a lex doid by acclamation congratulation st...
# 4                        thank you very much goex oo

# %%
from jiwer import wer
import jiwer

# transformation = jiwer.Compose([
#     jiwer.ToLowerCase(),
#     jiwer.RemoveMultipleSpaces(),
#     jiwer.RemoveWhiteSpace(replace_by_space=False),
#     jiwer.SentencesToListOfWords(word_delimiter=" ")
# ]) 

def calculate_wer(row):
    ground_truth = row.Transcription
    hypothesis = row.asr_output_preprocessed
    if not type(ground_truth) is str or not type(hypothesis) is str:
        print('return nan')
        return np.NaN
#     print(type(ground_truth), type(hypothesis))
#     WordErrRate = wer(ground_truth, hypothesis, truth_transform=transformation, 
#     hypothesis_transform=transformation)
    WordErrRate = wer(ground_truth, hypothesis)
    return WordErrRate

# %%
transcriptions_df['jiWER'] = transcriptions_df.apply(calculate_wer, axis=1)
transcriptions_df.head()
# Out:
# return nan
# return nan
#              Sound_file  Length (s)  \
# 0  016_20140701.wav.pcm          22
# 1  017_20140701.wav.pcm          27
# 2  018_20140701.wav.pcm          15
# 3  019_20140701.wav.pcm          23
# 4  020_20140701.wav.pcm          28
#
#                                        Transcription  nr_words  \
# 0  I would like to propose on behalf of the snd g...        33
# 1  no, I ask then the nominated candidate whether...        40
# 2  and as there is only one candidate, I would li...        43
# 3  so lets do it by acclamation, congratulation m...        24
# 4                     thank you very much colleagues         5
#
#    words per second                         preprocessed_transcription  \
# 0          1.500000  i would like to propose on behalf of the snd g...
# 1          1.481481  no i ask then the nominated candidate whether ...
# 2          2.866667  and as there is only one candidate i would lik...
# 3          1.043478  so lets do it by acclamation congratulation mi...
# 4          0.178571                     thank you very much colleagues
#
#                                           asr_output  \
# 0  I WOULD LIKE TO PROPOSE ON BEHALF OF THIES AND...
# 1  NO I ASK THAN A A DENOMINATED CANDIDE WETHER H...
# 2  AND AS THERE IS ONLY ONE CANDIDATE I WOULD LIK...
# 3  SO A LEX DOID BY ACCLAMATION CONGRATULATION ST...
# 4                        THANK YOU VERY MUCH GOEX OO
#
#                              asr_output_preprocessed     jiWER
# 0  i would like to propose on behalf of thies and...  0.606061
# 1  no i ask than a a denominated candide wether h...  0.525000
# 2  and as there is only one candidate i would lik...  0.232558
# 3  so a lex doid by acclamation congratulation st...  0.500000
# 4                        thank you very much goex oo  0.400000

# %%
def print_wers(row):
    print('truth :\n', row.preprocessed_transcription, end='\n---\n')
    print('hypothesis :\n', row.asr_output_preprocessed, end='\n---\n')
    print('WER:', f"{row.WER:.2f}")
    input()
    
# transcriptions_df.apply(print_wers, axis=1)

# %%
import pywer


def calculate_pywer(row):
    ground_truth = row.Transcription
    hypothesis = row.asr_output_preprocessed
    if not type(ground_truth) is str or not type(hypothesis) is str:
        print('return nan')
        return np.NaN
#     print(type(ground_truth), type(hypothesis))
    WordErrRate = pywer.wer([ground_truth], [hypothesis])/100
    return WordErrRate

# %%
transcriptions_df['pyWER'] = transcriptions_df.apply(calculate_pywer, axis=1)
transcriptions_df.head()
# Out:
# return nan
# return nan
#              Sound_file  Length (s)  \
# 0  016_20140701.wav.pcm          22
# 1  017_20140701.wav.pcm          27
# 2  018_20140701.wav.pcm          15
# 3  019_20140701.wav.pcm          23
# 4  020_20140701.wav.pcm          28
#
#                                        Transcription  nr_words  \
# 0  I would like to propose on behalf of the snd g...        33
# 1  no, I ask then the nominated candidate whether...        40
# 2  and as there is only one candidate, I would li...        43
# 3  so lets do it by acclamation, congratulation m...        24
# 4                     thank you very much colleagues         5
#
#    words per second                         preprocessed_transcription  \
# 0          1.500000  i would like to propose on behalf of the snd g...
# 1          1.481481  no i ask then the nominated candidate whether ...
# 2          2.866667  and as there is only one candidate i would lik...
# 3          1.043478  so lets do it by acclamation congratulation mi...
# 4          0.178571                     thank you very much colleagues
#
#                                           asr_output  \
# 0  I WOULD LIKE TO PROPOSE ON BEHALF OF THIES AND...
# 1  NO I ASK THAN A A DENOMINATED CANDIDE WETHER H...
# 2  AND AS THERE IS ONLY ONE CANDIDATE I WOULD LIK...
# 3  SO A LEX DOID BY ACCLAMATION CONGRATULATION ST...
# 4                        THANK YOU VERY MUCH GOEX OO
#
#                              asr_output_preprocessed     jiWER     pyWER
# 0  i would like to propose on behalf of thies and...  0.606061  0.606061
# 1  no i ask than a a denominated candide wether h...  0.525000  0.525000
# 2  and as there is only one candidate i would lik...  0.232558  0.232558
# 3  so a lex doid by acclamation congratulation st...  0.500000  0.500000
# 4                        thank you very much goex oo  0.400000  0.400000

# %%
import sys
import numpy


def editDistance(r, h):
    '''
    This function is to calculate the edit distance of reference sentence and the hypothesis sentence.

    Main algorithm used is dynamic programming.

    Attributes: 
        r -> the list of words produced by splitting reference sentence.
        h -> the list of words produced by splitting hypothesis sentence.
    '''
    d = numpy.zeros((len(r)+1)*(len(h)+1), dtype=numpy.uint8).reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        d[i][0] = i
    for j in range(len(h)+1):
        d[0][j] = j
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitute = d[i-1][j-1] + 1
                insert = d[i][j-1] + 1
                delete = d[i-1][j] + 1
                d[i][j] = min(substitute, insert, delete)
    return d

def getStepList(r, h, d):
    '''
    This function is to get the list of steps in the process of dynamic programming.

    Attributes: 
        r -> the list of words produced by splitting reference sentence.
        h -> the list of words produced by splitting hypothesis sentence.
        d -> the matrix built when calulating the editting distance of h and r.
    '''
    x = len(r)
    y = len(h)
    list = []
    while True:
        if x == 0 and y == 0: 
            break
        elif x >= 1 and y >= 1 and d[x][y] == d[x-1][y-1] and r[x-1] == h[y-1]: 
            list.append("e")
            x = x - 1
            y = y - 1
        elif y >= 1 and d[x][y] == d[x][y-1]+1:
            list.append("i")
            x = x
            y = y - 1
        elif x >= 1 and y >= 1 and d[x][y] == d[x-1][y-1]+1:
            list.append("s")
            x = x - 1
            y = y - 1
        else:
            list.append("d")
            x = x - 1
            y = y
    return list[::-1]

def alignedPrint(list, r, h, result):
    '''
    This funcition is to print the result of comparing reference and hypothesis sentences in an aligned way.
    
    Attributes:
        list   -> the list of steps.
        r      -> the list of words produced by splitting reference sentence.
        h      -> the list of words produced by splitting hypothesis sentence.
        result -> the rate calculated based on edit distance.
    '''
    print("REF:", end=" ")
    for i in range(len(list)):
        if list[i] == "i":
            count = 0
            for j in range(i):
                if list[j] == "d":
                    count += 1
            index = i - count
            print(" "*(len(h[index])), end=" ")
        elif list[i] == "s":
            count1 = 0
            for j in range(i):
                if list[j] == "i":
                    count1 += 1
            index1 = i - count1
            count2 = 0
            for j in range(i):
                if list[j] == "d":
                    count2 += 1
            index2 = i - count2
            if len(r[index1]) < len(h[index2]):
                print(r[index1] + " " * (len(h[index2])-len(r[index1])), end=" ")
            else:
                print(r[index1], end=" "),
        else:
            count = 0
            for j in range(i):
                if list[j] == "i":
                    count += 1
            index = i - count
            print(r[index], end=" "),
    print("\nHYP:", end=" ")
    for i in range(len(list)):
        if list[i] == "d":
            count = 0
            for j in range(i):
                if list[j] == "i":
                    count += 1
            index = i - count
            print(" " * (len(r[index])), end=" ")
        elif list[i] == "s":
            count1 = 0
            for j in range(i):
                if list[j] == "i":
                    count1 += 1
            index1 = i - count1
            count2 = 0
            for j in range(i):
                if list[j] == "d":
                    count2 += 1
            index2 = i - count2
            if len(r[index1]) > len(h[index2]):
                print(h[index2] + " " * (len(r[index1])-len(h[index2])), end=" ")
            else:
                print(h[index2], end=" ")
        else:
            count = 0
            for j in range(i):
                if list[j] == "d":
                    count += 1
            index = i - count
            print(h[index], end=" ")
    print("\nEVA:", end=" ")
    for i in range(len(list)):
        if list[i] == "d":
            count = 0
            for j in range(i):
                if list[j] == "i":
                    count += 1
            index = i - count
            print("D" + " " * (len(r[index])-1), end=" ")
        elif list[i] == "i":
            count = 0
            for j in range(i):
                if list[j] == "d":
                    count += 1
            index = i - count
            print("I" + " " * (len(h[index])-1), end=" ")
        elif list[i] == "s":
            count1 = 0
            for j in range(i):
                if list[j] == "i":
                    count1 += 1
            index1 = i - count1
            count2 = 0
            for j in range(i):
                if list[j] == "d":
                    count2 += 1
            index2 = i - count2
            if len(r[index1]) > len(h[index2]):
                print("S" + " " * (len(r[index1])-1), end=" ")
            else:
                print("S" + " " * (len(h[index2])-1), end=" ")
        else:
            count = 0
            for j in range(i):
                if list[j] == "i":
                    count += 1
            index = i - count
            print(" " * (len(r[index])), end=" ")
    print("\nWER: " + result)

def mywer(r, h):
    """
    This is a function that calculate the word error rate in ASR.
    You can use it like this: wer("what is it".split(), "what is".split()) 
    """
    # build the matrix
    d = editDistance(r, h)

    # find out the manipulation steps
    list = getStepList(r, h, d)

    # print the result in aligned way
    result = float(d[len(r)][len(h)]) / len(r) * 100
    
    return result

# %%
def calculate_mywer(row):
    ground_truth = row.Transcription
    hypothesis = row.asr_output_preprocessed
    if not type(ground_truth) is str or not type(hypothesis) is str:
        print('return nan')
        return np.NaN
#     print(type(ground_truth), type(hypothesis))
    WordErrRate = mywer(ground_truth.split(' '), hypothesis.split(' '))/100
    return WordErrRate

# %%
from tqdm import tqdm
tqdm.pandas()
transcriptions_df['myWER'] = transcriptions_df.progress_apply(calculate_mywer, axis=1)
transcriptions_df.head()
# Out:
# /home/hugo/anaconda3/lib/python3.7/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
#   0%|          | 0/101 [00:00<?, ?it/s]
# return nan
# 100%|██████████| 101/101 [00:02<00:00, 47.57it/s]
# return nan
#              Sound_file  Length (s)  \
# 0  016_20140701.wav.pcm          22
# 1  017_20140701.wav.pcm          27
# 2  018_20140701.wav.pcm          15
# 3  019_20140701.wav.pcm          23
# 4  020_20140701.wav.pcm          28
#
#                                        Transcription  nr_words  \
# 0  I would like to propose on behalf of the snd g...        33
# 1  no, I ask then the nominated candidate whether...        40
# 2  and as there is only one candidate, I would li...        43
# 3  so lets do it by acclamation, congratulation m...        24
# 4                     thank you very much colleagues         5
#
#    words per second                         preprocessed_transcription  \
# 0          1.500000  i would like to propose on behalf of the snd g...
# 1          1.481481  no i ask then the nominated candidate whether ...
# 2          2.866667  and as there is only one candidate i would lik...
# 3          1.043478  so lets do it by acclamation congratulation mi...
# 4          0.178571                     thank you very much colleagues
#
#                                           asr_output  \
# 0  I WOULD LIKE TO PROPOSE ON BEHALF OF THIES AND...
# 1  NO I ASK THAN A A DENOMINATED CANDIDE WETHER H...
# 2  AND AS THERE IS ONLY ONE CANDIDATE I WOULD LIK...
# 3  SO A LEX DOID BY ACCLAMATION CONGRATULATION ST...
# 4                        THANK YOU VERY MUCH GOEX OO
#
#                              asr_output_preprocessed     jiWER     pyWER  \
# 0  i would like to propose on behalf of thies and...  0.606061  0.606061
# 1  no i ask than a a denominated candide wether h...  0.525000  0.525000
# 2  and as there is only one candidate i would lik...  0.232558  0.232558
# 3  so a lex doid by acclamation congratulation st...  0.500000  0.500000
# 4                        thank you very much goex oo  0.400000  0.400000
#
#       myWER
# 0  0.606061
# 1  0.525000
# 2  0.232558
# 3  0.500000
# 4  0.400000

# %%
transcriptions_df.to_csv("evaluations.csv", sep='\t')
os.path.exists("evaluations.csv")
# Out:
# True

# %%
pywer.wer(transcriptions_df.preprocessed_transcription, transcriptions_df.asr_output_preprocessed)
# Out:
# 35.092724679029956

# %%
pywer.cer(transcriptions_df.preprocessed_transcription, transcriptions_df.asr_output_preprocessed)
# Out:
# 23.805329222638186

# %%
transcriptions_df_sorted = transcriptions_df.sort_values(by='jiWER', ascending=False)
transcriptions_df_sorted
# Out:
#                Sound_file  Length (s)  \
# 22   066_20140723.wav.pcm          21
# 41   002_20140915.wav.pcm          18
# 40   001_20140915.wav.pcm          27
# 100  232_20141211.wav.pcm          29
# 99   147_20141120.wav.pcm          17
# ..                    ...         ...
# 24   068_20140723.wav.pcm          21
# 87   175_20141110.wav.pcm          21
# 30   448_20140904.wav.pcm          28
# 5    021_20140701.wav.pcm          16
# 90   137_20141120.wav.pcm          22
#
#                                          Transcription  nr_words  \
# 22    misses brjork, well on behalf of the GUE ngl ...        11
# 41   yes, I would like to raise a point regarding p...        10
# 40   so that’s good, okay colleagues, if there are ...        27
# 100  now, with regard to ehm ehm ehm ehm, protectio...        60
# 99   It is important to recall that at the local le...        56
# ..                                                 ...       ...
# 24   I am glad that the, inside the directive we ar...        38
# 87   the next point on the agenda is the presention...        42
# 30   about fundamental rights, does it bring about ...        69
# 5                                                  NaN         0
# 90                                                 NaN         0
#
#      words per second                         preprocessed_transcription  \
# 22           0.523810   misses brjork well on behalf of the gue ngl g...
# 41           0.555556  yes i would like to raise a point regarding pr...
# 40           1.000000  so that s good okay colleagues if there are no...
# 100          2.068966  now with regard to ehm ehm ehm ehm protection ...
# 99           3.294118  it is important to recall that at the local le...
# ..                ...                                                ...
# 24           1.809524  i am glad that the inside the directive we are...
# 87           2.000000  the next point on the agenda is the presention...
# 30           2.464286  about fundamental rights does it bring about a...
# 5            0.000000
# 90           0.000000
#
#                                             asr_output  \
# 22   DEAR MISSUS BEORG AND YET EH YOU EVRONGUI WELL...
# 41   OPER SCULAT THAT'S IT INKEMURGED YES I WOULD L...
# 40   HAVEN'T THEY SO THAT'S GOOD LOOK IT COLLEAGUES...
# 100
# 99
# ..                                                 ...
# 24   I AM GLAD THAT THE INSIDE THE DIRECTIVE WE ARE...
# 87   THE NEXT POINT ON THE ADGENDER IS THE PRESENTI...
# 30   ABOUT FUNAMENAL RIGHTS DOES IT BRING ABOUT ANY...
# 5
# 90
#
#                                asr_output_preprocessed     jiWER     pyWER  \
# 22   dear missus beorg and yet eh you evrongui well...  1.100000  1.100000
# 41   oper sculat that s it inkemurged yes i would l...  1.100000  1.100000
# 40   haven t they so that s good look it colleagues...  1.074074  1.074074
# 100                                                     1.000000  1.000000
# 99                                                      1.000000  1.000000
# ..                                                 ...       ...       ...
# 24   i am glad that the inside the directive we are...  0.184211  0.184211
# 87   the next point on the adgender is the presenti...  0.166667  0.166667
# 30   about funamenal rights does it bring about any...  0.159420  0.159420
# 5                                                            NaN       NaN
# 90                                                           NaN       NaN
#
#         myWER
# 22   1.000000
# 41   1.100000
# 40   1.074074
# 100  1.000000
# 99   0.982143
# ..        ...
# 24   0.184211
# 87   0.166667
# 30   0.159420
# 5         NaN
# 90        NaN
#
# [101 rows x 11 columns]

# %%
transcriptions_df_sorted.to_csv("evaluations_sorted.csv", sep='\t')
os.path.exists("evaluations_sorted.csv")
# Out:
# True
