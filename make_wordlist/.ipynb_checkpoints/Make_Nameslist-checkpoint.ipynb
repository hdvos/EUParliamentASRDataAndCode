# %%
ls
# Out:
# Make_Nameslist.ipynb  names_and_name_parts.txt
# MEP_db.csv            names_permutations_3.txt

# %%
from csv import DictReader
from tqdm import tqdm_notebook
names = set()

with open("MEP_db.csv", 'rt') as f:
    rdr = DictReader(f)
    for line in tqdm_notebook(rdr, total = 8000):
#         input(line)
        name = line['MEP_name']
        
        start_date = line['start_date']
        if not start_date == '':
            try:
                start_year = int(start_date[:4])
            except:
                start_year = 0
        else:
            start_year = 0
        
        end_date = line['end_date']
        if not end_date == '':
            try:
                end_year = int(end_date[:4])
            except:
                end_year = 0
        else:
            end_year = 0
        
        if (2014 <= start_year <= 2018) or (2015 <= end_year <= 2019):
#             print(name, start_date, end_date)
            names.add(name)
names = list(names)
# Out:
# ...
# Rachida Dati 2014-07-01
# Andrus Ansip 2014-07-01 2014-10-31
# Norbert Neuser 2014-05-25
# Kerstin Westphal 2014-05-25
# Klaus Buchner 2014-07-01 2019-07-01
# Werner Langen 2014-05-25
# Ulrike Lunacek 2014-07-01 2017-11-08
# István Ujhelyi 2014-07-01
# Krisztina Morvai 2014-07-01
# Inés Ayala 2014-07-01 2019-07-01
# Lojze Peterle 2014-07-01
# Izaskun Bilbao Barandica 2014-07-01 2019-07-01
# Theodoros Zagorakis 2014-07-01
# Joachim Schuster 2014-05-25
# Georgi Pirinski, Jr. 2014-07-01
# Ramón Jáuregui 2014-07-01 2019-07-01
# Marc Tarabella 2014-07-01
# David Sassoli 2014-07-01
# Agnes Jongerius 2014-07-01
# Hilde Vautmans 2015-01-01
# Ivan Jakovčić 2014-07-01
# Jean-Paul Denanot 2014-07-01 2018-06-10
# Nicolas Bay 2014-07-01 2015-06-14
# Nicolas Bay 2015-06-15
# Nikólaos Chountís 2014-07-01
# Ryszard Legutko 2014-07-01
# Barbara Spinelli 2014-07-01
# Innocenzo Leontini 2018-08-20
# Olaf Stuger 2015-06-15
# Olaf Stuger 2014-07-01 2015-06-14
# ...

# %%
print(len(names))
# Out:
# 4622

# %%
print(names[:10])
# Out:
# ['Luigi Alberto Colajanni', 'Paul Rübig', 'Ernesto Caccavale', 'Carlo Stella', 'Graham Booth', 'Yves Fremion', 'Michel Scarbonchi', 'Danielle Auroi', 'Luís Filipe Nascimento Madeira', 'Marlene Lenz']

# %%
import itertools

order = 3

new_names = []

for name in names:
    name_split = name.split()
    for name in names

# %%
with open("names_permutations_3.txt", 'wt') as out:
    for name in new_names:
#         input(name)
        out.write(f"{name}\n")

# %%
new_names = []
for name in names:
    new_names.append(name)
    name_split = name.split()
    new_names.append(name_split[0])
    new_names.append(name_split[-1])

# %%
with open("names_and_name_parts.txt", 'wt') as out:
    for name in new_names:
#         input(name)
        out.write(f"{name}\n")

# %%
import itertools

stuff = [1, 2, 3]
for L in range(0, len(stuff)+1):
    for subset in itertools.combinations(stuff, L):
        print(subset)
# Out:
# ()
# (1,)
# (2,)
# (3,)
# (1, 2)
# (1, 3)
# (2, 3)
# (1, 2, 3)
