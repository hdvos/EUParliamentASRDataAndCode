# %%
transcriptions_loc = "/media/hugo/Seagate Expansion Drive/ALICE_BACKUP/voshpde/asr_huggingface/divided_scripts/python_scripts/the_transcripts"
wav_for_transcription_loc = "/media/hugo/Seagate Expansion Drive/WORK/files_for_transcription"

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import sox
data = []
for root, folders, files in os.walk(wav_for_transcription_loc):
    for filenm in files:
        file_id = os.path.splitext( os.path.splitext(filenm)[0])[0]
        
        filenr, motherfile = file_id.split('_')
#          = file_id.split('_')[1]
        
        transcription_file_name = os.path.join(transcriptions_loc, motherfile, filenm + '.txt')
        
        try:
            with open(transcription_file_name, 'rt') as f:
                transcription_text = f.read()
        except Exception:
            continue
        
        length_in_secs = sox.file_info.duration(os.path.join(root, filenm))
#         input(length_in_secs)
        
        data.append( {
            'filenr' : filenr,
            'motherfile': motherfile,
            'asr_output': transcription_text,
            'manual_transcription': transcription_text,
            'manually_checked': 0,
            'duration': length_in_secs,
            'wavfile_location': os.path.join(root, filenm),
            'transcription_location': transcription_file_name
            
        })
#         print(transcription_text)
# Out:
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# ...
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.
# This install of SoX cannot process .pcm files.

# %%
import pandas as pd

output_csv_name = 'semi_manual_transcripts.csv'

data_df = pd.DataFrame.from_dict(data)
data_df.to_csv(output_csv_name, sep='\t')
assert os.path.exists(output_csv_name)

# %%
data_df
# Out:
#      filenr  ...                             transcription_location
# 0       016  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# 1       017  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# 2       018  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# 3       019  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# 4       020  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# ...     ...  ...                                                ...
# 1395    196  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# 1396    197  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# 1397    198  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# 1398    199  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
# 1399    200  ...  /media/hugo/Seagate Expansion Drive/ALICE_BACK...
#
# [1400 rows x 8 columns]

# %%
data_df.duration.sum() / 60 / 60
# Out:
# 8.768527777777779
